# %%
# Simple login check using dictionary

users = {
    "sameer": "1234",
    "ali": "abcd",
    "john": "pass"
}

username = input("Enter username: ")
password = input("Enter password: ")

if username in users and users[username] == password:
    print(password is correct)
else:
    print(password is incorrect)

# %%
# Simple login check using dictionary

users = {
 "username":"sameer",
  "password":"1234"
}

username = input("Enter username: ")
password = input("Enter password: ")
for i in range(3):
    if username == users["username"] and users["password"] == password:
      print("password is correct")
    else:
     print("password is incorrect")

# %%
count =1
while count <= 6:
    print ("number: ", count)
    count += 1
# Out:
# number:  1
# number:  2
# number:  3
# number:  4
# number:  5
# number:  6

# %%
while count <=6
# Out:
#   Cell In[13], line 1
#     while count <=6
#                     ^
# SyntaxError: expected ':'

# %%
correct_pin = "123"
entered_pin = ""
while entered_pin != correct_pin:
    entered_pin = input("please enter your pin")
    print ("acess granted")
# Out:
# please enter your pin 1
# acess granted
# please enter your pin 2
# acess granted
# please enter your pin 123
# acess granted

# %%
# Simple login system using dictionary

users = {"username": "sameer", "password": "1234"}

choice = input("Do you want to Sign Up (1) or Sign In (2)? ")

if choice == "1":
    users["username"] = input("Enter new username: ")
    users["password"] = input("Enter new password: ")
    print("Account created successfully!")

elif choice == "2":
    for i in range(3):
        username = input("Enter username: ")
        password = input("Enter password: ")
        if username == users["username"] and password == users["password"]:
            print("Password is correct! Access granted.")
            break
        else:
            print("Password is incorrect. Try again!")
else:
    print("Invalid choice.")
